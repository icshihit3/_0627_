# %%
import pandas as pd
df1=pd.read_csv("aqx_p_488.csv")
df1
# Out:
#      sitename county  aqi pollutant status  so2    co    o3  o3_8hr  pm10  \
# 0      屏東(枋山)    屏東縣   16       NaN     良好  0.1  0.00  20.3    17.2     9
# 1    大甲（日南國小）    臺中市   12       NaN     良好  0.7  0.21  32.3    13.2    13
# 2      新北(樹林)    新北市   35       NaN     良好  0.5  0.23  15.1     7.2    15
# 3      屏東（琉球）    屏東縣   28       NaN     良好  0.6   NaN  21.5    15.2    17
# 4      臺南（麻豆）    臺南市   34       NaN     良好  1.2  0.17  35.9    10.3    24
# ..        ...    ...  ...       ...    ...  ...   ...   ...     ...   ...
# 995        頭份    苗栗縣   29       NaN     良好  1.4  0.21  22.7    30.7    18
# 996        新竹    新竹市   27       NaN     良好  0.9  0.28  20.5    30.0    19
# 997        竹東    新竹縣   28       NaN     良好  0.5  0.17  12.5    30.7    23
# 998        湖口    新竹縣   33       NaN     良好  2.1  0.32  14.5    25.0    21
# 999        龍潭    桃園市   36       NaN     良好  0.6  0.21  14.3    30.0    19
#
#      ...  winddirec  datacreationdate  unit  co_8hr pm2.5_avg pm10_avg  \
# ...
